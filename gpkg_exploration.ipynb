# %%
#Imports
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import matplotlib.pyplot as plt

DATA_LOC = os.getenv("DATA_LOC")
print(DATA_LOC)
# Out:
# C:\Users\e99ku\OneDrive\Dokumenty\Data Science in Business and Entrepreunership\Master\Semester 2\DCiA\Heijmans_data

# %%
#Loading the data
gdf1 = gpd.read_file(DATA_LOC + "\\2025-cbs_vk100_2024_v1\\cbs_vk100_2024_v1.gpkg")
gdf2 = gpd.read_file(DATA_LOC + "\\2025-cbs_vk500_2024_v1\\cbs_vk500_2024_v1.gpkg")

# %%
print(gdf1.shape)
# Out:
# (392107, 132)

# %%
gdf1.head()
# Out:
#   crs28992res100m  aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# 0      E2054N6114                5         -99997          -99997
# 1      E2062N6110                5         -99997          -99997
# 2      E2069N6109               10         -99997               5
# 3      E2075N6109                5         -99997               5
# 4      E2078N6109               10              5          -99997
#
#    aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# 0                         -99997                          -99997
# 1                         -99997                          -99997
# 2                         -99997                          -99997
# 3                         -99997                          -99997
# 4                         -99997                          -99997
#
#    aantal_inwoners_25_tot_45_jaar  aantal_inwoners_45_tot_65_jaar  \
# 0                          -99997                          -99997
# 1                          -99997                          -99997
# 2                          -99997                          -99997
# 3                          -99997                          -99997
# 4                          -99997                          -99997
#
#    aantal_inwoners_65_jaar_en_ouder  aantal_geboorten  ...  \
# 0                            -99997            -99995  ...
# 1                                 5            -99995  ...
# 2                            -99997            -99995  ...
# 3                            -99997            -99995  ...
# 4                            -99997            -99995  ...
#
#    ziekenhuis_excl_buitenpoli_aantal_binnen_5_km  \
# 0                                       -99995.0
# 1                                       -99995.0
# 2                                       -99995.0
# 3                                       -99995.0
# 4                                       -99995.0
#
#    ziekenhuis_excl_buitenpoli_aantal_binnen_10_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    ziekenhuis_excl_buitenpoli_aantal_binnen_20_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    dichtstbijzijnde_ziekenh_incl_buitenpoli_afst_in_km  \
# 0                                           -99995.0
# 1                                           -99995.0
# 2                                           -99995.0
# 3                                           -99995.0
# 4                                           -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_5_km  \
# 0                                       -99995.0
# 1                                       -99995.0
# 2                                       -99995.0
# 3                                       -99995.0
# 4                                       -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_10_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_20_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    dichtstbijzijnde_apotheek_afstand_in_km  \
# 0                                 -99995.0
# 1                                 -99995.0
# 2                                 -99995.0
# 3                                 -99995.0
# 4                                 -99995.0
#
#    dichtstbijzijnde_huisartsenpost_afstand_in_km  \
# 0                                       -99995.0
# 1                                       -99995.0
# 2                                       -99995.0
# 3                                       -99995.0
# 4                                       -99995.0
#
#                                             geometry
# 0  MULTIPOLYGON (((205400 611500, 205500 611500, ...
# 1  MULTIPOLYGON (((206200 611100, 206300 611100, ...
# 2  MULTIPOLYGON (((206900 611000, 207000 611000, ...
# 3  MULTIPOLYGON (((207500 611000, 207600 611000, ...
# 4  MULTIPOLYGON (((207800 611000, 207900 611000, ...
#
# [5 rows x 132 columns]

# %%
gdf1.info()
print(gdf1.crs)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 392107 entries, 0 to 392106
# Columns: 132 entries, crs28992res100m to geometry
# dtypes: float64(93), geometry(1), int32(37), str(1)
# memory usage: 339.5 MB
# EPSG:28992

# %%
gdf1_web = gdf1.to_crs(epsg=3857)
fig, ax = plt.subplots(figsize=(10,10))
gdf1_web.plot(ax=ax)
plt.show()
#I have no idea what this is suppose to be...

# %%
gdf1.columns
# Out:
# Index(['crs28992res100m', 'aantal_inwoners', 'aantal_mannen', 'aantal_vrouwen',
#        'aantal_inwoners_0_tot_15_jaar', 'aantal_inwoners_15_tot_25_jaar',
#        'aantal_inwoners_25_tot_45_jaar', 'aantal_inwoners_45_tot_65_jaar',
#        'aantal_inwoners_65_jaar_en_ouder', 'aantal_geboorten',
#        ...
#        'ziekenhuis_excl_buitenpoli_aantal_binnen_5_km',
#        'ziekenhuis_excl_buitenpoli_aantal_binnen_10_km',
#        'ziekenhuis_excl_buitenpoli_aantal_binnen_20_km',
#        'dichtstbijzijnde_ziekenh_incl_buitenpoli_afst_in_km',
#        'ziekenhuis_incl_buitenpoli_aantal_binnen_5_km',
#        'ziekenhuis_incl_buitenpoli_aantal_binnen_10_km',
#        'ziekenhuis_incl_buitenpoli_aantal_binnen_20_km',
#        'dichtstbijzijnde_apotheek_afstand_in_km',
#        'dichtstbijzijnde_huisartsenpost_afstand_in_km', 'geometry'],
#       dtype='str', length=132)

# %% [markdown]
# Firt column: coordinates.

# %%
print(gdf2.shape)
# Out:
# (151108, 137)

# %%
gdf2.head()
# Out:
#   crs28992res500m  aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# 0      E2260N6190           -99997         -99997          -99997
# 1      E2265N6190           -99997         -99997          -99997
# 2      E2270N6190           -99997         -99997          -99997
# 3      E2275N6190           -99997         -99997          -99997
# 4      E2280N6190           -99997         -99997          -99997
#
#    aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# 0                         -99997                          -99997
# 1                         -99997                          -99997
# 2                         -99997                          -99997
# 3                         -99997                          -99997
# 4                         -99997                          -99997
#
#    aantal_inwoners_25_tot_45_jaar  aantal_inwoners_45_tot_65_jaar  \
# 0                          -99997                          -99997
# 1                          -99997                          -99997
# 2                          -99997                          -99997
# 3                          -99997                          -99997
# 4                          -99997                          -99997
#
#    aantal_inwoners_65_jaar_en_ouder  aantal_geboorten  ...  \
# 0                            -99997            -99995  ...
# 1                            -99997            -99995  ...
# 2                            -99997            -99995  ...
# 3                            -99997            -99995  ...
# 4                            -99997            -99995  ...
#
#    ziekenhuis_excl_buitenpoli_aantal_binnen_20_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    dichtstbijzijnde_ziekenh_incl_buitenpoli_afst_in_km  \
# 0                                           -99995.0
# 1                                           -99995.0
# 2                                           -99995.0
# 3                                           -99995.0
# 4                                           -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_5_km  \
# 0                                       -99995.0
# 1                                       -99995.0
# 2                                       -99995.0
# 3                                       -99995.0
# 4                                       -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_10_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_20_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    dichtstbijzijnde_apotheek_afstand_in_km  \
# 0                                 -99995.0
# 1                                 -99995.0
# 2                                 -99995.0
# 3                                 -99995.0
# 4                                 -99995.0
#
#    dichtstbijzijnde_huisartsenpost_afstand_in_km  omgevingsadressendichtheid  \
# 0                                       -99995.0                      -99997
# 1                                       -99995.0                      -99997
# 2                                       -99995.0                      -99997
# 3                                       -99995.0                      -99997
# 4                                       -99995.0                      -99997
#
#    stedelijkheid                                           geometry
# 0         -99997  MULTIPOLYGON (((226000 619000, 226000 619500, ...
# 1         -99997  MULTIPOLYGON (((226500 619500, 227000 619500, ...
# 2         -99997  MULTIPOLYGON (((227000 619500, 227500 619500, ...
# 3         -99997  MULTIPOLYGON (((227500 619500, 228000 619500, ...
# 4         -99997  MULTIPOLYGON (((228000 619500, 228500 619500, ...
#
# [5 rows x 137 columns]

# %%
gdf2.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
gdf2_web = gdf2.to_crs(epsg=3857)
fig, ax = plt.subplots(figsize=(10,10))
gdf2_web.plot(ax=ax, alpha=0.6, edgecolor="black")
plt.show()

# %%
cols1 = set(gdf1.columns)
cols2 = set(gdf2.columns)

missing_in_file2 = cols1 - cols2
missing_in_file1 = cols2 - cols1

print("Columns in file1 but not in file2:", missing_in_file2)
print("Columns in file2 but not in file1:", missing_in_file1)
# Out:
# Columns in file1 but not in file2: {'crs28992res100m'}
# Columns in file2 but not in file1: {'crs28992res500m', 'stedelijkheid', 'percentage_hoog_inkomen_huishouden', 'percentage_laag_inkomen_huishouden', 'omgevingsadressendichtheid', 'gemiddeld_inkomen_huishouden'}

# %% [markdown]
# Translated columns in the file 2, but not in the file 1:
# * stedelijkheid - 'urbanity',
# * percentage_hoog_inkomen_huishouden - percentage_high_income_households,
# * percentage_laag_inkomen_huishouden - percentage_low_income_households,
# * omgevingsadressendichtheid - environmental_address_density,
# * gemiddeld_inkomen_huishouden - average_household_income
